# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/CSA1702/blob/main/Smart_Ac_AI_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("===== SMART AC AI AGENT =====")

temperature = int(input("Enter room temperature (°C): "))

print("\nAI Agent is observing the environment...")

if temperature >= 30:
    print("Decision: Turn ON the Air
    Conditioner")
else:
    print("Decision: Turn OFF the Air Conditioner")
# Out:
# 67
# 45
# Fan Speed Medium
