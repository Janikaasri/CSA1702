# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/CSA1702/blob/main/colors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
colors = ["Red", "Green", "Blue"]

for stateA in colors:
    for stateB in colors:

        # Constraint: Adjacent states cannot have same color
        if stateA != stateB:
            print("State A =", stateA,
                  "State B =", stateB)
