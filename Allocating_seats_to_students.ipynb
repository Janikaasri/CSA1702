# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/CSA1702/blob/main/Allocating_seats_to_students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables (Students)
students = ["A", "B", "C"]

# Domain (Available Seats)
seats = [1, 2, 3]

# Dictionary to store assignments
assignment = {}

# Function to check whether assigning a seat is valid
def is_valid(student, seat):
    # Constraint 1: A cannot sit in Seat 2
    if student == "A" and seat == 2:
        return False

    # Constraint 2: No two students can have the same seat
    if seat in assignment.values():
        return False

    return True

# Backtracking algorithm
def backtrack(index):
    # If all students are assigned
    if index == len(students):
        return True

    student = students[index]

    # Try every seat
    for seat in seats:
        if is_valid(student, seat):
            assignment[student] = seat

            if backtrack(index + 1):
                return True

            # Backtrack
            del assignment[student]

    return False

# Solve the CSP
if backtrack(0):
    print("Solution Found:")
    for student, seat in assignment.items():
        print(f"{student} --> Seat {seat}")
else:
    print("No solution exists.")
# Out:
# Solution Found:
# A --> Seat 1
# B --> Seat 2
# C --> Seat 3
