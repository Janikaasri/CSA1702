# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/CSA1702/blob/main/knowledge_based_reasoning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Knowledge Base
weather = "rainy"

# Reasoning
if weather == "rainy":
    print("Knowledge: It is rainy.")
    print("Reasoning: Carry an umbrella.")
else:
    print("Knowledge: Weather is clear.")
    print("Reasoning: No umbrella needed.")
# Out:
# Knowledge: It is rainy.
# Reasoning: Carry an umbrella.
